# %%
from kafka import KafkaProducer,KafkaAdminClient
from kafka.admin import NewTopic
import logging
import json

def create_kafka_topic(topic_name,num_partitions=1,replication_factor=1):
    admin_client = KafkaAdminClient(bootstrap_servers = 'localhost:9092',
                                    client_id = 'GalalEwida-client')
    topic = NewTopic(name=topic_name,
                     num_partitions=num_partitions,
                     replication_factor=replication_factor)
    try:
        admin_client.create_topics(new_topics=[topic],
                                   validate_only=False)
        print(f"Topic '{topic_name}' created successfully.")
    except Exception as e:
        print(f"Error creating topic: {e}")


    
def get_kafka_producer():
    try:
        return KafkaProducer(
            bootstrap_servers="localhost:9092",
            value_serializer=lambda value: json.dumps(value).encode('utf-8'),
            key_serializer=lambda key: str(key).encode('utf-8'),
            acks='all',
            retries=5,  # Increased for better resilience
            max_in_flight_requests_per_connection=5,
            request_timeout_ms=10000,
            linger_ms=5,
            batch_size=32000,
            partitioner=lambda key, all_partitions, available_partitions: (
                hash(key) % len(all_partitions) if key is not None else 0
            )
        )
    except Exception as e:
        logging.error(f"Error creating Kafka producer: {e}")
        raise

# %%
import pandas as pd
import time
def fraudulent_data_generator(file_path):
    df = pd.read_csv(file_path)
    for _,row in df.iterrows():
        yield row.to_dict()

def set_orders(producer,topic_name,data_generator):
    topic_name = topic_name

    for i,fraud_data in enumerate(data_generator):
            YN = fraud_data['is-Fraud']
            producer.send(topic_name,key = YN,value=fraud_data )
            print("Produced record:", i,", to topic:", topic_name,"in partition :",YN)
            time.sleep(2)
    producer.flush()
    producer.close()

# %%
# import sys
# from pathlib import Path
# sys.path.append(str(Path(__file__).resolve().parent.parent))
import pandas as pd
import logging
from config.Kafka_config import create_kafka_topic,get_kafka_producer
from src.data_generator import fraudulent_data_generator,set_orders


def main():
    #load_dataset
    topic_name = "New-Topic"
    file_path = r"dataset\fraud-dataset.csv"
    fraudulent_dataset_generator = fraudulent_data_generator(file_path=file_path)
    producer = get_kafka_producer()
    #create a new topic
    create_kafka_topic(topic_name=topic_name,num_partitions=3,replication_factor=1)
    set_orders(producer=producer,topic_name=topic_name,data_generator=fraudulent_dataset_generator)



if __name__ == "__main__":
    main()
# Out:
# Topic 'New-Topic' created successfully.
# Produced record: 0 , to topic: New-Topic in partition : No
# Produced record: 1 , to topic: New-Topic in partition : No
# Produced record: 2 , to topic: New-Topic in partition : No
# Produced record: 3 , to topic: New-Topic in partition : No
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 23
#      18     set_orders(producer=producer,topic_name=topic_name,data_generator=fraudulent_dataset_generator)
#      22 if __name__ == "__main__":
# ---> 23     main()
#
# Cell In[5], line 18, in main()
#      16 #create a new topic
#      17 create_kafka_topic(topic_name=topic_name,num_partitions=3,replication_factor=1)
# ---> 18 set_orders(producer=producer,topic_name=topic_name,data_generator=fraudulent_dataset_generator)
#
# File d:\SIA\Kafka-Flink\src\data_generator.py:15, in set_orders(producer, topic_name, data_generator)
#      13         producer.send(topic_name,key = YN,value=fraud_data )
#      14         print("Produced record:", i,", to topic:", topic_name,"in partition :",YN)
# ---> 15         time.sleep(2)
#      16 producer.flush()
#      17 producer.close()
#
# KeyboardInterrupt:

# %%
from kafka import KafkaConsumer
import json

def create_kafka_consumer(topic_name, group_id=None):
    try:
        consumer = KafkaConsumer(
            topic_name,
            bootstrap_servers='localhost:9092',
            auto_offset_reset='earliest',  # Start reading from the beginning of the topic
            enable_auto_commit=True,
            group_id=group_id,  # Optional: add a consumer group ID
            value_deserializer=lambda x: json.loads(x.decode('utf-8')),  # Deserialize JSON messages
            key_deserializer=lambda x: x.decode('utf-8') if x else None  # Deserialize keys
        )
        return consumer
    except Exception as e:
        print(f"Error creating Kafka consumer: {e}")
        return None

def consume_messages(topic_name, group_id=None):
    consumer = create_kafka_consumer(topic_name, group_id)
    
    if consumer is None:
        return
    
    try:
        print(f"Starting to consume messages from topic: {topic_name}")
        for message in consumer:
            try:
                # Print detailed message information
                print(f"Topic: {message.topic}")
                print(f"Partition: {message.partition}")
                print(f"Offset: {message.offset}")
                print(f"Key: {message.key}")
                print(f"Value: {message.value}")
                print("-" * 50)
            except Exception as e:
                print(f"Error processing message: {e}")
    
    except KeyboardInterrupt:
        print("Stopping consumer...")
    finally:
        consumer.close()

# Usage
if __name__ == "__main__":
    consume_messages("New-Topic")  # Use the exact topic name from producer
# Out:
# Starting to consume messages from topic: New-Topic
# Topic: New-Topic
# Partition: 2
# Offset: 0
# Key: No
# Value: {'step': 283, 'type': 'CASH_IN', 'amount': 210329.84, 'nameOrig': 'C1159819632', 'is-Fraud': 'No'}
# --------------------------------------------------
# Topic: New-Topic
# Partition: 2
# Offset: 1
# Key: No
# Value: {'step': 132, 'type': 'CASH_OUT', 'amount': 215489.19, 'nameOrig': 'C1372369468', 'is-Fraud': 'No'}
# --------------------------------------------------
# Topic: New-Topic
# Partition: 2
# Offset: 2
# Key: No
# Value: {'step': 355, 'type': 'DEBIT', 'amount': 4431.05, 'nameOrig': 'C1059822709', 'is-Fraud': 'No'}
# --------------------------------------------------
# Topic: New-Topic
# Partition: 2
# Offset: 3
# Key: No
# Value: {'step': 135, 'type': 'CASH_OUT', 'amount': 214026.2, 'nameOrig': 'C1464960643', 'is-Fraud': 'No'}
# --------------------------------------------------
# Stopping consumer...

# %%
from kafka import KafkaAdminClient
from kafka.admin import NewTopic,config_resource,ConfigResourceType
from kafka.errors import TopicAlreadyExistsError, UnknownTopicOrPartitionError

# %%
admin_client = KafkaAdminClient(bootstrap_servers="localhost:9092")
admin_client.delete_topics(['New-Topic'])
admin_client.close()

# %%
from kafka import KafkaProducer, KafkaAdminClient
from kafka.admin import NewTopic
import json
import time

# %%
def create_kafka_topic():
    admin_client = KafkaAdminClient(bootstrap_servers='localhost:9092', client_id="admin-client")
    
    topic_name = "orders"
    num_partitions = 4
    replication_factor = 1  # Adjust based on your cluster
    
    topic = NewTopic(name=topic_name, num_partitions=num_partitions, replication_factor=replication_factor)
    
    try:
        admin_client.create_topics(new_topics=[topic], validate_only=False)
        print(f"Topic '{topic_name}' created successfully.")
    except Exception as e:
        print(f"Error creating topic: {e}")
    
create_kafka_topic()
# Out:
# Topic 'orders' created successfully.

# %%
def get_kafka_producer():
    return KafkaProducer(
        bootstrap_servers='localhost:9092',
        key_serializer=str.encode,  # Ensure the key is encoded as bytes
        value_serializer=lambda v: json.dumps(v).encode('utf-8'),
        partitioner=lambda key, all_partitions, available_partitions: hash(key) % len(all_partitions),
    )

# %%
def send_orders(producer):
    regions = ["North", "South", "East", "West"]
    topic_name = "orders"

    for i in range(100):
        region = regions[i % len(regions)]  # Rotate through regions
        order = {
            "order_id": i + 1,
            "item": f"Item-{i+1}",
            "region": region,
            "price": round(100 + i * 1.5, 2)
        }
        
        print(f"Sending order {order} to region {region}.")
        producer.send(topic_name, key=region, value=order)

    # Ensure all messages are sent before closing
    producer.flush()

producer = get_kafka_producer()
send_orders(producer)
# Out:
# Sending order {'order_id': 1, 'item': 'Item-1', 'region': 'North', 'price': 100.0} to region North.
# Sending order {'order_id': 2, 'item': 'Item-2', 'region': 'South', 'price': 101.5} to region South.
# Sending order {'order_id': 3, 'item': 'Item-3', 'region': 'East', 'price': 103.0} to region East.
# Sending order {'order_id': 4, 'item': 'Item-4', 'region': 'West', 'price': 104.5} to region West.
# Sending order {'order_id': 5, 'item': 'Item-5', 'region': 'North', 'price': 106.0} to region North.
# Sending order {'order_id': 6, 'item': 'Item-6', 'region': 'South', 'price': 107.5} to region South.
# Sending order {'order_id': 7, 'item': 'Item-7', 'region': 'East', 'price': 109.0} to region East.
# Sending order {'order_id': 8, 'item': 'Item-8', 'region': 'West', 'price': 110.5} to region West.
# Sending order {'order_id': 9, 'item': 'Item-9', 'region': 'North', 'price': 112.0} to region North.
# Sending order {'order_id': 10, 'item': 'Item-10', 'region': 'South', 'price': 113.5} to region South.
# Sending order {'order_id': 11, 'item': 'Item-11', 'region': 'East', 'price': 115.0} to region East.
# Sending order {'order_id': 12, 'item': 'Item-12', 'region': 'West', 'price': 116.5} to region West.
# Sending order {'order_id': 13, 'item': 'Item-13', 'region': 'North', 'price': 118.0} to region North.
# Sending order {'order_id': 14, 'item': 'Item-14', 'region': 'South', 'price': 119.5} to region South.
# Sending order {'order_id': 15, 'item': 'Item-15', 'region': 'East', 'price': 121.0} to region East.
# Sending order {'order_id': 16, 'item': 'Item-16', 'region': 'West', 'price': 122.5} to region West.
# Sending order {'order_id': 17, 'item': 'Item-17', 'region': 'North', 'price': 124.0} to region North.
# Sending order {'order_id': 18, 'item': 'Item-18', 'region': 'South', 'price': 125.5} to region South.
# Sending order {'order_id': 19, 'item': 'Item-19', 'region': 'East', 'price': 127.0} to region East.
# Sending order {'order_id': 20, 'item': 'Item-20', 'region': 'West', 'price': 128.5} to region West.
# Sending order {'order_id': 21, 'item': 'Item-21', 'region': 'North', 'price': 130.0} to region North.
# Sending order {'order_id': 22, 'item': 'Item-22', 'region': 'South', 'price': 131.5} to region South.
# Sending order {'order_id': 23, 'item': 'Item-23', 'region': 'East', 'price': 133.0} to region East.
# Sending order {'order_id': 24, 'item': 'Item-24', 'region': 'West', 'price': 134.5} to region West.
# Sending order {'order_id': 25, 'item': 'Item-25', 'region': 'North', 'price': 136.0} to region North.
# Sending order {'order_id': 26, 'item': 'Item-26', 'region': 'South', 'price': 137.5} to region South.
# Sending order {'order_id': 27, 'item': 'Item-27', 'region': 'East', 'price': 139.0} to region East.
# Sending order {'order_id': 28, 'item': 'Item-28', 'region': 'West', 'price': 140.5} to region West.
# Sending order {'order_id': 29, 'item': 'Item-29', 'region': 'North', 'price': 142.0} to region North.
# Sending order {'order_id': 30, 'item': 'Item-30', 'region': 'South', 'price': 143.5} to region South.
# Sending order {'order_id': 31, 'item': 'Item-31', 'region': 'East', 'price': 145.0} to region East.
# Sending order {'order_id': 32, 'item': 'Item-32', 'region': 'West', 'price': 146.5} to region West.
# Sending order {'order_id': 33, 'item': 'Item-33', 'region': 'North', 'price': 148.0} to region North.
# Sending order {'order_id': 34, 'item': 'Item-34', 'region': 'South', 'price': 149.5} to region South.
# Sending order {'order_id': 35, 'item': 'Item-35', 'region': 'East', 'price': 151.0} to region East.
# Sending order {'order_id': 36, 'item': 'Item-36', 'region': 'West', 'price': 152.5} to region West.
# Sending order {'order_id': 37, 'item': 'Item-37', 'region': 'North', 'price': 154.0} to region North.
# Sending order {'order_id': 38, 'item': 'Item-38', 'region': 'South', 'price': 155.5} to region South.
# Sending order {'order_id': 39, 'item': 'Item-39', 'region': 'East', 'price': 157.0} to region East.
# Sending order {'order_id': 40, 'item': 'Item-40', 'region': 'West', 'price': 158.5} to region West.
# Sending order {'order_id': 41, 'item': 'Item-41', 'region': 'North', 'price': 160.0} to region North.
# Sending order {'order_id': 42, 'item': 'Item-42', 'region': 'South', 'price': 161.5} to region South.
# Sending order {'order_id': 43, 'item': 'Item-43', 'region': 'East', 'price': 163.0} to region East.
# Sending order {'order_id': 44, 'item': 'Item-44', 'region': 'West', 'price': 164.5} to region West.
# Sending order {'order_id': 45, 'item': 'Item-45', 'region': 'North', 'price': 166.0} to region North.
# Sending order {'order_id': 46, 'item': 'Item-46', 'region': 'South', 'price': 167.5} to region South.
# Sending order {'order_id': 47, 'item': 'Item-47', 'region': 'East', 'price': 169.0} to region East.
# Sending order {'order_id': 48, 'item': 'Item-48', 'region': 'West', 'price': 170.5} to region West.
# Sending order {'order_id': 49, 'item': 'Item-49', 'region': 'North', 'price': 172.0} to region North.
# Sending order {'order_id': 50, 'item': 'Item-50', 'region': 'South', 'price': 173.5} to region South.
# Sending order {'order_id': 51, 'item': 'Item-51', 'region': 'East', 'price': 175.0} to region East.
# Sending order {'order_id': 52, 'item': 'Item-52', 'region': 'West', 'price': 176.5} to region West.
# Sending order {'order_id': 53, 'item': 'Item-53', 'region': 'North', 'price': 178.0} to region North.
# Sending order {'order_id': 54, 'item': 'Item-54', 'region': 'South', 'price': 179.5} to region South.
# Sending order {'order_id': 55, 'item': 'Item-55', 'region': 'East', 'price': 181.0} to region East.
# Sending order {'order_id': 56, 'item': 'Item-56', 'region': 'West', 'price': 182.5} to region West.
# Sending order {'order_id': 57, 'item': 'Item-57', 'region': 'North', 'price': 184.0} to region North.
# Sending order {'order_id': 58, 'item': 'Item-58', 'region': 'South', 'price': 185.5} to region South.
# Sending order {'order_id': 59, 'item': 'Item-59', 'region': 'East', 'price': 187.0} to region East.
# Sending order {'order_id': 60, 'item': 'Item-60', 'region': 'West', 'price': 188.5} to region West.
# Sending order {'order_id': 61, 'item': 'Item-61', 'region': 'North', 'price': 190.0} to region North.
# Sending order {'order_id': 62, 'item': 'Item-62', 'region': 'South', 'price': 191.5} to region South.
# Sending order {'order_id': 63, 'item': 'Item-63', 'region': 'East', 'price': 193.0} to region East.
# Sending order {'order_id': 64, 'item': 'Item-64', 'region': 'West', 'price': 194.5} to region West.
# Sending order {'order_id': 65, 'item': 'Item-65', 'region': 'North', 'price': 196.0} to region North.
# Sending order {'order_id': 66, 'item': 'Item-66', 'region': 'South', 'price': 197.5} to region South.
# Sending order {'order_id': 67, 'item': 'Item-67', 'region': 'East', 'price': 199.0} to region East.
# Sending order {'order_id': 68, 'item': 'Item-68', 'region': 'West', 'price': 200.5} to region West.
# Sending order {'order_id': 69, 'item': 'Item-69', 'region': 'North', 'price': 202.0} to region North.
# Sending order {'order_id': 70, 'item': 'Item-70', 'region': 'South', 'price': 203.5} to region South.
# Sending order {'order_id': 71, 'item': 'Item-71', 'region': 'East', 'price': 205.0} to region East.
# Sending order {'order_id': 72, 'item': 'Item-72', 'region': 'West', 'price': 206.5} to region West.
# Sending order {'order_id': 73, 'item': 'Item-73', 'region': 'North', 'price': 208.0} to region North.
# Sending order {'order_id': 74, 'item': 'Item-74', 'region': 'South', 'price': 209.5} to region South.
# Sending order {'order_id': 75, 'item': 'Item-75', 'region': 'East', 'price': 211.0} to region East.
# Sending order {'order_id': 76, 'item': 'Item-76', 'region': 'West', 'price': 212.5} to region West.
# Sending order {'order_id': 77, 'item': 'Item-77', 'region': 'North', 'price': 214.0} to region North.
# Sending order {'order_id': 78, 'item': 'Item-78', 'region': 'South', 'price': 215.5} to region South.
# Sending order {'order_id': 79, 'item': 'Item-79', 'region': 'East', 'price': 217.0} to region East.
# Sending order {'order_id': 80, 'item': 'Item-80', 'region': 'West', 'price': 218.5} to region West.
# Sending order {'order_id': 81, 'item': 'Item-81', 'region': 'North', 'price': 220.0} to region North.
# Sending order {'order_id': 82, 'item': 'Item-82', 'region': 'South', 'price': 221.5} to region South.
# Sending order {'order_id': 83, 'item': 'Item-83', 'region': 'East', 'price': 223.0} to region East.
# Sending order {'order_id': 84, 'item': 'Item-84', 'region': 'West', 'price': 224.5} to region West.
# Sending order {'order_id': 85, 'item': 'Item-85', 'region': 'North', 'price': 226.0} to region North.
# Sending order {'order_id': 86, 'item': 'Item-86', 'region': 'South', 'price': 227.5} to region South.
# Sending order {'order_id': 87, 'item': 'Item-87', 'region': 'East', 'price': 229.0} to region East.
# Sending order {'order_id': 88, 'item': 'Item-88', 'region': 'West', 'price': 230.5} to region West.
# Sending order {'order_id': 89, 'item': 'Item-89', 'region': 'North', 'price': 232.0} to region North.
# Sending order {'order_id': 90, 'item': 'Item-90', 'region': 'South', 'price': 233.5} to region South.
# Sending order {'order_id': 91, 'item': 'Item-91', 'region': 'East', 'price': 235.0} to region East.
# Sending order {'order_id': 92, 'item': 'Item-92', 'region': 'West', 'price': 236.5} to region West.
# Sending order {'order_id': 93, 'item': 'Item-93', 'region': 'North', 'price': 238.0} to region North.
# Sending order {'order_id': 94, 'item': 'Item-94', 'region': 'South', 'price': 239.5} to region South.
# Sending order {'order_id': 95, 'item': 'Item-95', 'region': 'East', 'price': 241.0} to region East.
# Sending order {'order_id': 96, 'item': 'Item-96', 'region': 'West', 'price': 242.5} to region West.
# Sending order {'order_id': 97, 'item': 'Item-97', 'region': 'North', 'price': 244.0} to region North.
# Sending order {'order_id': 98, 'item': 'Item-98', 'region': 'South', 'price': 245.5} to region South.
# Sending order {'order_id': 99, 'item': 'Item-99', 'region': 'East', 'price': 247.0} to region East.
# Sending order {'order_id': 100, 'item': 'Item-100', 'region': 'West', 'price': 248.5} to region West.
